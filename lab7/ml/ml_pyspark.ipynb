# %%
#!pip install pyspark

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import IntegerType, FloatType, LongType, StringType, DoubleType
from pyspark.sql.dataframe import DataFrame
from pyspark.sql.functions import col
from pyspark.sql import SparkSession
from pyspark.ml import Pipeline, Transformer
from pyspark.ml.feature import StringIndexer, VectorAssembler, Imputer
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml.evaluation import BinaryClassificationEvaluator
import pyspark.sql.functions as F
from itertools import combinations
import os

# %% [markdown]
# ## Check Python Path

# %%
import sys
sys.executable
# Out:
# '/tmp/demos/bin/python3'

# %%
DATA_FOLDER = "data"

NUMBER_OF_FOLDS = 3
SPLIT_SEED = 7576
TRAIN_TEST_SPLIT = 0.8

# %% [markdown]
# ## Function for data reading

# %%
def read_data(spark: SparkSession) -> DataFrame:
    """
    read data; since the data has the header we let spark guess the schema
    """
    
    # Read the Titanic CSV data into a DataFrame
    titanic_data = spark.read \
        .format("csv") \
        .option("header", "true") \
        .option("inferSchema", "true") \
        .load(os.path.join(DATA_FOLDER,"*.csv"))

    return titanic_data

# %% [markdown]
# ## Writing new Transformer type class : adding cross product of features

# %%
class PairwiseProduct(Transformer):

    def __init__(self, inputCols, outputCols):
        self.__inputCols = inputCols
        self.__outputCols = outputCols

        self._paramMap = self._params = {}

    def _transform(self, df):
        for cols, out_col in zip(self.__inputCols, self.__outputCols):
            df = df.withColumn(out_col, col(cols[0]) * col(cols[1]))
        return df

# %%
class SquareProduct(Transformer):
    def __init__(self, inputCols, outputCols):
        self.__inputCols = inputCols
        self.__outputCols = outputCols
        self._paramMap = self._params = {}

    def _transform(self, df):
        for in_col, out_col in zip(self.__inputCols, self.__outputCols):
            df = df.withColumn(out_col, col(in_col) ** 2)
        return df

# %% [markdown]
# ## The ML pipeline

# %%
def pipeline(data: DataFrame):

    """
    every attribute that is numeric is non-categorical; this is questionable
    """

    numeric_features = [f.name for f in data.schema.fields if isinstance(f.dataType, DoubleType) or isinstance(f.dataType, FloatType) or isinstance(f.dataType, IntegerType) or isinstance(f.dataType, LongType)]
    string_features = [f.name for f in data.schema.fields if isinstance(f.dataType, StringType)]
    numeric_features.remove("PassengerId")
    numeric_features.remove("Survived")
    string_features.remove("Name")

    # index string features; map string to consecutive integers - it should be one hot encoding 
    name_indexed_string_columns = [f"{v}Index" for v in string_features] 
    # we must have keep so that we can impute them in the next step
    indexer = StringIndexer(inputCols=string_features, outputCols=name_indexed_string_columns, handleInvalid='keep')

    # Fill missing values; strategy can be mode, median, mean
    # string columns
    imputed_columns_string = [f"Imputed{v}" for v in name_indexed_string_columns]
    imputers_string = []
    for org_col_name, indexed_col_name, imputed_col_name in zip(string_features, name_indexed_string_columns, imputed_columns_string):
        number_of_categories = data.select(F.countDistinct(org_col_name)).take(1)[0].asDict()[f'count(DISTINCT {org_col_name})'] # this is the value that needs to be imputed based on the keep option above
        imputers_string.append(Imputer(inputCol=indexed_col_name, outputCol=imputed_col_name, strategy = "mode", missingValue=number_of_categories))
    # numeric columns
    imputed_columns_numeric = [f"Imputed{v}" for v in numeric_features]
    imputer_numeric = Imputer(inputCols=numeric_features, outputCols=imputed_columns_numeric, strategy = "mean")

    # Create all pairwise products of numeric features
    all_pairs = [v for v in combinations(imputed_columns_numeric, 2)]
    pairwise_columns = [f"{col1}_{col2}" for col1, col2 in all_pairs]
    pairwise_product = PairwiseProduct(inputCols=all_pairs, outputCols=pairwise_columns)

    square_cols = [f"{col}_2" for col in imputed_columns_numeric]
    square_product = SquareProduct(inputCols=imputed_columns_numeric, outputCols=square_cols)

    # Assemble feature columns into a single feature vector
    assembler = VectorAssembler(
        inputCols=pairwise_columns + imputed_columns_numeric + imputed_columns_string, 
        outputCol="features"
        )

    # Define a Random Forest classifier
    classifier = RandomForestClassifier(labelCol="Survived", featuresCol="features")

    # Create the pipeline
    pipeline = Pipeline(stages=[indexer, *imputers_string, imputer_numeric, pairwise_product, square_product, assembler, classifier])
    
    paramGrid = ParamGridBuilder() \
        .addGrid(classifier.maxDepth, [2, 4, 6, 8, 10]) \
        .addGrid(classifier.numTrees, [10, 100, 1000, 5000]) \
        .build()

    # Set up the cross-validator
    evaluator = BinaryClassificationEvaluator(labelCol="Survived", rawPredictionCol="rawPrediction", metricName="areaUnderROC")
    crossval = CrossValidator(
        estimator=pipeline,
        estimatorParamMaps=paramGrid,
        evaluator=evaluator,
        numFolds=NUMBER_OF_FOLDS,
        seed=SPLIT_SEED)

    # Split the data into training and test sets
    train_data, test_data = data.randomSplit([TRAIN_TEST_SPLIT, 1-TRAIN_TEST_SPLIT], seed=SPLIT_SEED)

    # Train the cross-validated pipeline model
    cvModel = crossval.fit(train_data)

    # Make predictions on the test data
    predictions = cvModel.transform(test_data)

    # Evaluate the model
    auc = evaluator.evaluate(predictions)
    print(f"Area Under ROC Curve: {auc:.4f}")

    # Get the best RandomForest model
    best_model = cvModel.bestModel.stages[-1]

    # Retrieve the selected maximum tree depth
    selected_max_depth = best_model.getOrDefault(best_model.getParam("maxDepth"))

    # Print the selected maximum tree depth
    print(f"Selected Maximum Tree Depth: {selected_max_depth}")

# %%
def main():
    # Create a Spark session
    spark = SparkSession.builder \
        .appName("Predict Titanic Survival") \
        .getOrCreate()

    data = read_data(spark)
    pipeline(data)

    spark.stop()
    
main()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/05/23 17:41:00 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/05/23 17:41:18 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 24/05/23 17:41:21 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:41:25 WARN DAGScheduler: Broadcasting large task binary with size 11.5 MiB
# 24/05/23 17:41:33 WARN DAGScheduler: Broadcasting large task binary with size 1111.2 KiB
# 24/05/23 17:41:34 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 24/05/23 17:41:35 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/23 17:41:39 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:41:42 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 24/05/23 17:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1680.2 KiB
# 24/05/23 17:41:47 WARN DAGScheduler: Broadcasting large task binary with size 9.6 MiB
# 24/05/23 17:41:50 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 24/05/23 17:41:54 WARN DAGScheduler: Broadcasting large task binary with size 16.4 MiB
# 24/05/23 17:42:01 WARN DAGScheduler: Broadcasting large task binary with size 1111.2 KiB
# 24/05/23 17:42:02 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 24/05/23 17:42:02 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 24/05/23 17:42:04 WARN DAGScheduler: Broadcasting large task binary with size 5.4 MiB
# 24/05/23 17:42:06 WARN DAGScheduler: Broadcasting large task binary with size 5.5 MiB
# 24/05/23 17:42:09 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:42:12 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 24/05/23 17:42:15 WARN DAGScheduler: Broadcasting large task binary with size 1680.2 KiB
# 24/05/23 17:42:16 WARN DAGScheduler: Broadcasting large task binary with size 9.6 MiB
# 24/05/23 17:42:20 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 24/05/23 17:42:23 WARN DAGScheduler: Broadcasting large task binary with size 16.8 MiB
# 24/05/23 17:42:26 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 24/05/23 17:42:30 WARN DAGScheduler: Broadcasting large task binary with size 26.5 MiB
# 24/05/23 17:42:34 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 24/05/23 17:42:40 WARN DAGScheduler: Broadcasting large task binary with size 26.8 MiB
# 24/05/23 17:42:45 WARN DAGScheduler: Broadcasting large task binary with size 1189.1 KiB
# 24/05/23 17:42:48 WARN DAGScheduler: Broadcasting large task binary with size 1111.2 KiB
# 24/05/23 17:42:49 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 24/05/23 17:42:50 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 24/05/23 17:42:51 WARN DAGScheduler: Broadcasting large task binary with size 5.4 MiB
# 24/05/23 17:42:53 WARN DAGScheduler: Broadcasting large task binary with size 7.7 MiB
# 24/05/23 17:42:55 WARN DAGScheduler: Broadcasting large task binary with size 10.1 MiB
# 24/05/23 17:42:57 WARN DAGScheduler: Broadcasting large task binary with size 8.0 MiB
# 24/05/23 17:43:01 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:43:04 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 24/05/23 17:43:08 WARN DAGScheduler: Broadcasting large task binary with size 1680.2 KiB
# 24/05/23 17:43:10 WARN DAGScheduler: Broadcasting large task binary with size 9.6 MiB
# 24/05/23 17:43:13 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 24/05/23 17:43:16 WARN DAGScheduler: Broadcasting large task binary with size 16.8 MiB
# 24/05/23 17:43:22 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 24/05/23 17:43:27 WARN DAGScheduler: Broadcasting large task binary with size 26.5 MiB
# 24/05/23 17:43:32 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 24/05/23 17:43:40 WARN DAGScheduler: Broadcasting large task binary with size 37.7 MiB
# 24/05/23 17:43:45 WARN DAGScheduler: Broadcasting large task binary with size 4.7 MiB
# 24/05/23 17:43:51 WARN DAGScheduler: Broadcasting large task binary with size 49.6 MiB
# 24/05/23 17:43:56 WARN DAGScheduler: Broadcasting large task binary with size 4.7 MiB
# 24/05/23 17:44:05 WARN DAGScheduler: Broadcasting large task binary with size 39.4 MiB
# 24/05/23 17:44:12 WARN DAGScheduler: Broadcasting large task binary with size 1189.1 KiB
# 24/05/23 17:44:12 WARN DAGScheduler: Broadcasting large task binary with size 1412.4 KiB
# 24/05/23 17:44:13 WARN DAGScheduler: Broadcasting large task binary with size 1609.5 KiB
# 24/05/23 17:44:13 WARN DAGScheduler: Broadcasting large task binary with size 1194.6 KiB
# 24/05/23 17:44:15 WARN DAGScheduler: Broadcasting large task binary with size 1111.2 KiB
# 24/05/23 17:44:16 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 24/05/23 17:44:17 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 24/05/23 17:44:18 WARN DAGScheduler: Broadcasting large task binary with size 5.4 MiB
# 24/05/23 17:44:20 WARN DAGScheduler: Broadcasting large task binary with size 7.7 MiB
# 24/05/23 17:44:22 WARN DAGScheduler: Broadcasting large task binary with size 10.1 MiB
# 24/05/23 17:44:25 WARN DAGScheduler: Broadcasting large task binary with size 12.3 MiB
# 24/05/23 17:44:28 WARN DAGScheduler: Broadcasting large task binary with size 14.2 MiB
# 24/05/23 17:44:31 WARN DAGScheduler: Broadcasting large task binary with size 10.2 MiB
# 24/05/23 17:44:35 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:44:38 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 24/05/23 17:44:41 WARN DAGScheduler: Broadcasting large task binary with size 1680.2 KiB
# 24/05/23 17:44:43 WARN DAGScheduler: Broadcasting large task binary with size 9.6 MiB
# 24/05/23 17:44:47 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 24/05/23 17:44:50 WARN DAGScheduler: Broadcasting large task binary with size 16.8 MiB
# 24/05/23 17:44:54 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 24/05/23 17:44:59 WARN DAGScheduler: Broadcasting large task binary with size 26.5 MiB
# 24/05/23 17:45:04 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 24/05/23 17:45:10 WARN DAGScheduler: Broadcasting large task binary with size 37.7 MiB
# 24/05/23 17:45:15 WARN DAGScheduler: Broadcasting large task binary with size 4.7 MiB
# 24/05/23 17:45:22 WARN DAGScheduler: Broadcasting large task binary with size 49.6 MiB
# 24/05/23 17:45:27 WARN DAGScheduler: Broadcasting large task binary with size 4.7 MiB
# 24/05/23 17:45:34 WARN DAGScheduler: Broadcasting large task binary with size 60.8 MiB
# 24/05/23 17:45:40 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 24/05/23 17:45:48 WARN DAGScheduler: Broadcasting large task binary with size 70.6 MiB
# 24/05/23 17:45:54 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 24/05/23 17:46:04 WARN DAGScheduler: Broadcasting large task binary with size 50.2 MiB
# 24/05/23 17:46:14 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 24/05/23 17:46:18 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:46:22 WARN DAGScheduler: Broadcasting large task binary with size 11.5 MiB
# 24/05/23 17:46:29 WARN DAGScheduler: Broadcasting large task binary with size 1115.6 KiB
# 24/05/23 17:46:30 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:46:32 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 24/05/23 17:46:35 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:46:39 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 24/05/23 17:46:42 WARN DAGScheduler: Broadcasting large task binary with size 1721.5 KiB
# 24/05/23 17:46:44 WARN DAGScheduler: Broadcasting large task binary with size 9.8 MiB
# 24/05/23 17:46:48 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 24/05/23 17:46:52 WARN DAGScheduler: Broadcasting large task binary with size 16.9 MiB
# 24/05/23 17:46:59 WARN DAGScheduler: Broadcasting large task binary with size 1115.6 KiB
# 24/05/23 17:47:00 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:47:01 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 24/05/23 17:47:03 WARN DAGScheduler: Broadcasting large task binary with size 5.8 MiB
# 24/05/23 17:47:05 WARN DAGScheduler: Broadcasting large task binary with size 5.8 MiB
# 24/05/23 17:47:08 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:47:12 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 24/05/23 17:47:15 WARN DAGScheduler: Broadcasting large task binary with size 1721.5 KiB
# 24/05/23 17:47:17 WARN DAGScheduler: Broadcasting large task binary with size 9.8 MiB
# 24/05/23 17:47:20 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 24/05/23 17:47:23 WARN DAGScheduler: Broadcasting large task binary with size 17.6 MiB
# 24/05/23 17:47:28 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 24/05/23 17:47:32 WARN DAGScheduler: Broadcasting large task binary with size 28.3 MiB
# 24/05/23 17:47:37 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 24/05/23 17:47:44 WARN DAGScheduler: Broadcasting large task binary with size 28.3 MiB
# 24/05/23 17:47:50 WARN DAGScheduler: Broadcasting large task binary with size 1011.8 KiB
# 24/05/23 17:47:50 WARN DAGScheduler: Broadcasting large task binary with size 1282.3 KiB
# 24/05/23 17:47:51 WARN DAGScheduler: Broadcasting large task binary with size 1033.2 KiB
# 24/05/23 17:47:53 WARN DAGScheduler: Broadcasting large task binary with size 1115.6 KiB
# 24/05/23 17:47:54 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:47:55 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 24/05/23 17:47:57 WARN DAGScheduler: Broadcasting large task binary with size 5.8 MiB
# 24/05/23 17:47:59 WARN DAGScheduler: Broadcasting large task binary with size 8.3 MiB
# 24/05/23 17:48:00 WARN DAGScheduler: Broadcasting large task binary with size 1028.4 KiB
# 24/05/23 17:48:01 WARN DAGScheduler: Broadcasting large task binary with size 10.8 MiB
# 24/05/23 17:48:04 WARN DAGScheduler: Broadcasting large task binary with size 8.5 MiB
# 24/05/23 17:48:09 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:48:13 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 24/05/23 17:48:16 WARN DAGScheduler: Broadcasting large task binary with size 1721.5 KiB
# 24/05/23 17:48:18 WARN DAGScheduler: Broadcasting large task binary with size 9.8 MiB
# 24/05/23 17:48:23 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 24/05/23 17:48:25 WARN DAGScheduler: Broadcasting large task binary with size 17.6 MiB
# 24/05/23 17:48:29 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 24/05/23 17:48:34 WARN DAGScheduler: Broadcasting large task binary with size 28.3 MiB
# 24/05/23 17:48:39 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 24/05/23 17:48:44 WARN DAGScheduler: Broadcasting large task binary with size 40.5 MiB
# 24/05/23 17:48:49 WARN DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 24/05/23 17:48:56 WARN DAGScheduler: Broadcasting large task binary with size 53.1 MiB
# 24/05/23 17:49:01 WARN DAGScheduler: Broadcasting large task binary with size 4.7 MiB
# 24/05/23 17:49:09 WARN DAGScheduler: Broadcasting large task binary with size 41.9 MiB
# 24/05/23 17:49:15 WARN DAGScheduler: Broadcasting large task binary with size 1011.8 KiB
# 24/05/23 17:49:15 WARN DAGScheduler: Broadcasting large task binary with size 1282.3 KiB
# 24/05/23 17:49:15 WARN DAGScheduler: Broadcasting large task binary with size 1515.2 KiB
# 24/05/23 17:49:15 WARN DAGScheduler: Broadcasting large task binary with size 1706.4 KiB
# 24/05/23 17:49:16 WARN DAGScheduler: Broadcasting large task binary with size 1255.8 KiB
# 24/05/23 17:49:18 WARN DAGScheduler: Broadcasting large task binary with size 1115.6 KiB
# 24/05/23 17:49:19 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:49:20 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 24/05/23 17:49:21 WARN DAGScheduler: Broadcasting large task binary with size 5.8 MiB
# 24/05/23 17:49:23 WARN DAGScheduler: Broadcasting large task binary with size 8.3 MiB
# 24/05/23 17:49:24 WARN DAGScheduler: Broadcasting large task binary with size 1028.4 KiB
# 24/05/23 17:49:26 WARN DAGScheduler: Broadcasting large task binary with size 10.8 MiB
# 24/05/23 17:49:28 WARN DAGScheduler: Broadcasting large task binary with size 13.0 MiB
# 24/05/23 17:49:30 WARN DAGScheduler: Broadcasting large task binary with size 14.8 MiB
# 24/05/23 17:49:33 WARN DAGScheduler: Broadcasting large task binary with size 10.6 MiB
# 24/05/23 17:49:37 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:49:41 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 24/05/23 17:49:45 WARN DAGScheduler: Broadcasting large task binary with size 1721.5 KiB
# 24/05/23 17:49:47 WARN DAGScheduler: Broadcasting large task binary with size 9.8 MiB
# 24/05/23 17:49:51 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 24/05/23 17:49:54 WARN DAGScheduler: Broadcasting large task binary with size 17.6 MiB
# 24/05/23 17:49:58 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 24/05/23 17:50:03 WARN DAGScheduler: Broadcasting large task binary with size 28.3 MiB
# 24/05/23 17:50:08 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 24/05/23 17:50:14 WARN DAGScheduler: Broadcasting large task binary with size 40.5 MiB
# 24/05/23 17:50:19 WARN DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 24/05/23 17:50:26 WARN DAGScheduler: Broadcasting large task binary with size 53.1 MiB
# 24/05/23 17:50:31 WARN DAGScheduler: Broadcasting large task binary with size 4.7 MiB
# 24/05/23 17:50:38 WARN DAGScheduler: Broadcasting large task binary with size 64.2 MiB
# 24/05/23 17:50:43 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 24/05/23 17:50:51 WARN DAGScheduler: Broadcasting large task binary with size 73.2 MiB
# 24/05/23 17:50:56 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 24/05/23 17:51:04 WARN DAGScheduler: Broadcasting large task binary with size 52.3 MiB
# 24/05/23 17:51:12 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 24/05/23 17:51:16 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:51:21 WARN DAGScheduler: Broadcasting large task binary with size 11.6 MiB
# 24/05/23 17:51:27 WARN DAGScheduler: Broadcasting large task binary with size 1112.2 KiB
# 24/05/23 17:51:27 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:51:29 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 24/05/23 17:51:33 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:51:35 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 24/05/23 17:51:39 WARN DAGScheduler: Broadcasting large task binary with size 1695.9 KiB
# 24/05/23 17:51:40 WARN DAGScheduler: Broadcasting large task binary with size 9.7 MiB
# 24/05/23 17:51:43 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 24/05/23 17:51:47 WARN DAGScheduler: Broadcasting large task binary with size 16.9 MiB
# 24/05/23 17:51:54 WARN DAGScheduler: Broadcasting large task binary with size 1112.2 KiB
# 24/05/23 17:51:54 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:51:55 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 24/05/23 17:51:57 WARN DAGScheduler: Broadcasting large task binary with size 5.5 MiB
# 24/05/23 17:51:59 WARN DAGScheduler: Broadcasting large task binary with size 5.6 MiB
# 24/05/23 17:52:03 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:52:06 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 24/05/23 17:52:10 WARN DAGScheduler: Broadcasting large task binary with size 1695.9 KiB
# 24/05/23 17:52:12 WARN DAGScheduler: Broadcasting large task binary with size 9.7 MiB
# 24/05/23 17:52:15 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 24/05/23 17:52:18 WARN DAGScheduler: Broadcasting large task binary with size 17.1 MiB
# 24/05/23 17:52:23 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 24/05/23 17:52:27 WARN DAGScheduler: Broadcasting large task binary with size 26.8 MiB
# 24/05/23 17:52:31 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 24/05/23 17:52:37 WARN DAGScheduler: Broadcasting large task binary with size 27.4 MiB
# 24/05/23 17:52:43 WARN DAGScheduler: Broadcasting large task binary with size 1184.1 KiB
# 24/05/23 17:52:45 WARN DAGScheduler: Broadcasting large task binary with size 1112.2 KiB
# 24/05/23 17:52:46 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:52:47 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 24/05/23 17:52:48 WARN DAGScheduler: Broadcasting large task binary with size 5.5 MiB
# 24/05/23 17:52:50 WARN DAGScheduler: Broadcasting large task binary with size 7.6 MiB
# 24/05/23 17:52:53 WARN DAGScheduler: Broadcasting large task binary with size 9.9 MiB
# 24/05/23 17:52:56 WARN DAGScheduler: Broadcasting large task binary with size 8.0 MiB
# 24/05/23 17:52:59 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:53:02 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 24/05/23 17:53:06 WARN DAGScheduler: Broadcasting large task binary with size 1695.9 KiB
# 24/05/23 17:53:08 WARN DAGScheduler: Broadcasting large task binary with size 9.7 MiB
# 24/05/23 17:53:11 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 24/05/23 17:53:14 WARN DAGScheduler: Broadcasting large task binary with size 17.1 MiB
# 24/05/23 17:53:19 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 24/05/23 17:53:23 WARN DAGScheduler: Broadcasting large task binary with size 26.8 MiB
# 24/05/23 17:53:27 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 24/05/23 17:53:33 WARN DAGScheduler: Broadcasting large task binary with size 37.7 MiB
# 24/05/23 17:53:38 WARN DAGScheduler: Broadcasting large task binary with size 4.5 MiB
# 24/05/23 17:53:45 WARN DAGScheduler: Broadcasting large task binary with size 48.9 MiB
# 24/05/23 17:53:51 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 24/05/23 17:53:58 WARN DAGScheduler: Broadcasting large task binary with size 39.3 MiB
# 24/05/23 17:54:05 WARN DAGScheduler: Broadcasting large task binary with size 1184.1 KiB
# 24/05/23 17:54:05 WARN DAGScheduler: Broadcasting large task binary with size 1398.3 KiB
# 24/05/23 17:54:05 WARN DAGScheduler: Broadcasting large task binary with size 1581.2 KiB
# 24/05/23 17:54:06 WARN DAGScheduler: Broadcasting large task binary with size 1177.1 KiB
# 24/05/23 17:54:07 WARN DAGScheduler: Broadcasting large task binary with size 1112.2 KiB
# 24/05/23 17:54:08 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:54:09 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 24/05/23 17:54:11 WARN DAGScheduler: Broadcasting large task binary with size 5.5 MiB
# 24/05/23 17:54:13 WARN DAGScheduler: Broadcasting large task binary with size 7.6 MiB
# 24/05/23 17:54:14 WARN DAGScheduler: Broadcasting large task binary with size 9.9 MiB
# 24/05/23 17:54:17 WARN DAGScheduler: Broadcasting large task binary with size 11.9 MiB
# 24/05/23 17:54:19 WARN DAGScheduler: Broadcasting large task binary with size 13.7 MiB
# 24/05/23 17:54:22 WARN DAGScheduler: Broadcasting large task binary with size 9.8 MiB
# 24/05/23 17:54:26 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:54:29 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 24/05/23 17:54:33 WARN DAGScheduler: Broadcasting large task binary with size 1695.9 KiB
# 24/05/23 17:54:35 WARN DAGScheduler: Broadcasting large task binary with size 9.7 MiB
# 24/05/23 17:54:38 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 24/05/23 17:54:41 WARN DAGScheduler: Broadcasting large task binary with size 17.1 MiB
# 24/05/23 17:54:45 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 24/05/23 17:54:49 WARN DAGScheduler: Broadcasting large task binary with size 26.8 MiB
# 24/05/23 17:54:53 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 24/05/23 17:54:59 WARN DAGScheduler: Broadcasting large task binary with size 37.7 MiB
# 24/05/23 17:55:04 WARN DAGScheduler: Broadcasting large task binary with size 4.5 MiB
# 24/05/23 17:55:11 WARN DAGScheduler: Broadcasting large task binary with size 48.9 MiB
# 24/05/23 17:55:17 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 24/05/23 17:55:24 WARN DAGScheduler: Broadcasting large task binary with size 59.1 MiB
# 24/05/23 17:55:31 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 24/05/23 17:55:39 WARN DAGScheduler: Broadcasting large task binary with size 67.9 MiB
# 24/05/23 17:55:45 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 24/05/23 17:55:53 WARN DAGScheduler: Broadcasting large task binary with size 48.8 MiB
# 24/05/23 17:56:01 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/23 17:56:06 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 24/05/23 17:56:12 WARN DAGScheduler: Broadcasting large task binary with size 1734.9 KiB
# 24/05/23 17:56:13 WARN DAGScheduler: Broadcasting large task binary with size 9.9 MiB
# 24/05/23 17:56:19 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 24/05/23 17:56:22 WARN DAGScheduler: Broadcasting large task binary with size 16.9 MiB
# Area Under ROC Curve: 0.8807
# Selected Maximum Tree Depth: 4

# %% [markdown]
# Original Results before implementing Step 1 & 2:
#
# Area Under ROC Curve: 0.8662
#
# Selected Maximum Tree Depth: 6
#
# New Results after implementing Squared Features and Tree Depth:
#
# Area Under ROC Curve: 0.8807
#
# Selected Maximum Tree Depth: 4
#
# It seems like this increase in AUC ROC indicates a more robust and generalizable model. This is in part due to the squared features contributing to capturing non-linear relationships more effectively, and the change in number of trees and the subsequent reduction in tree depth may have helped in avoiding overfitting and better generalization. Overall these modifications that I made seem to help improve model accuracy in predictions!
